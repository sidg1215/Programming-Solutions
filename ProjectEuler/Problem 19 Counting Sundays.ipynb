# %%
totaldays = 1
days = 0
count = 0
for n in range(1901, 2001):
    i = 1
    while(i<13):
        if i<8:
            if i%2 == 1:
                days = 31
            if i%2 == 0:
                days = 30
        if i == 2:
            if n%4 == 0:
                days = 29
            if n%400 == 0:
                days = 29
            if n%4 <> 0:
                days = 28
        if i<13 and i>=8:
            if i%2 == 1:
                days = 30
            else:
                days = 31
        i = i + 1
        print days
        totaldays = days + totaldays
        print "Total days: ", totaldays
    if totaldays%7 == 5:
        count = count + 1
        print "Year: ",n
        print "Month: ", i
print count
# Out:
# 31
# Total days:  32
# 28
# Total days:  60
# 31
# Total days:  91
# 30
# Total days:  121
# 31
# Total days:  152
# 30
# Total days:  182
# 31
# Total days:  213
# 31
# Total days:  244
# 30
# Total days:  274
# 31
# Total days:  305
# 30
# Total days:  335
# 31
# Total days:  366
# 31
# Total days:  397
# 28
# Total days:  425
# 31
# Total days:  456
# 30
# Total days:  486
# 31
# Total days:  517
# 30
# Total days:  547
# 31
# Total days:  578
# 31
# Total days:  609
# 30
# Total days:  639
# 31
# Total days:  670
# 30
# Total days:  700
# 31
# Total days:  731
# 31
# Total days:  762
# 28
# Total days:  790
# 31
# Total days:  821
# 30
# Total days:  851
# 31
# Total days:  882
# 30
# Total days:  912
# 31
# Total days:  943
# 31
# Total days:  974
# 30
# Total days:  1004
# 31
# Total days:  1035
# 30
# Total days:  1065
# 31
# Total days:  1096
# 31
# Total days:  1127
# 29
# Total days:  1156
# 31
# Total days:  1187
# 30
# Total days:  1217
# 31
# Total days:  1248
# 30
# ...

# %%
(1+31+28+31)%7
# Out:
# 0
