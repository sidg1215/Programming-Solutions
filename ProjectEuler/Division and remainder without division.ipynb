# %%
num = 213323
divisor = 7
quotient = 0
remainder = 0

while divisor * quotient <= num:
    if num - divisor * quotient > 0 and num - divisor * quotient<num:
        print "Remainder for quotient of", quotient, " :",num - divisor * quotient
        remainder = num - divisor * quotient
    quotient = quotient + 1
if quotient * divisor > num:
    quotient = quotient - 1
remainder = num - quotient * divisor
print
print "Remainder: ", remainder
print "Quotient: ", quotient
# Out:
# Remainder for quotient of 1  : 213316
# Remainder for quotient of 2  : 213309
# Remainder for quotient of 3  : 213302
# Remainder for quotient of 4  : 213295
# Remainder for quotient of 5  : 213288
# Remainder for quotient of 6  : 213281
# Remainder for quotient of 7  : 213274
# Remainder for quotient of 8  : 213267
# Remainder for quotient of 9  : 213260
# Remainder for quotient of 10  : 213253
# Remainder for quotient of 11  : 213246
# Remainder for quotient of 12  : 213239
# Remainder for quotient of 13  : 213232
# Remainder for quotient of 14  : 213225
# Remainder for quotient of 15  : 213218
# Remainder for quotient of 16  : 213211
# Remainder for quotient of 17  : 213204
# Remainder for quotient of 18  : 213197
# Remainder for quotient of 19  : 213190
# Remainder for quotient of 20  : 213183
# Remainder for quotient of 21  : 213176
# Remainder for quotient of 22  : 213169
# Remainder for quotient of 23  : 213162
# Remainder for quotient of 24  : 213155
# ...

# %%
def remainder(n,d):
    r = n - d
    if r < d:
        return r
    else:
        return division(r,d)

# %%
remainder(94,101)
# Out:
# -7

# %%
902-94
# Out:
# 808

# %%
for x in range(1000):
    if x%101 == 7:
        print x
# Out:
# 7
# 108
# 209
# 310
# 411
# 512
# 613
# 714
# 815
# 916

# %%
33%7
# Out:
# 5

# %%
def division(n,d):
    return str(n) + ' = '+str(d)+'*'+str(n/d) +' + '+ str(n%d)

# %%
division(12,6)
# Out:
# '12 = 6*2 + 0'

# %%
def gcd(a,b):
    while

# %%
import random

# %%
gcd(321315,4554645)
# Out:
# 15

# %% [markdown]
# 5-----10 diff = 5, 5-----5 diff = 0, gcd = 5

# %%
321315
# Out:
# 0
